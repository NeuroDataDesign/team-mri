# %%
import nibabel as nib
import skimage.io as io
import numpy as np

# %% [raw]
# # the first fslmaths command:
# Extracting white matter edge ...
# fslmaths /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/anat/preproc/t1w_wm_thr.nii.gz -edge -bin -mas /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/anat/preproc/t1w_wm_thr.nii.gz /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/tmp/reg_a/t1w_wm_edge.nii.gz

# %%
t1w_wm_thr = nib.load('e:/fslmaths/t1w_wm_thr.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[46])
# Out:
# (96, 128, 128)

# %%
t1w_wm_thr = nib.load('e:/fslmaths/t1w_wm_edge.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[46])
# Out:
# (96, 128, 128)

# %% [raw]
# fslmaths /home/jialinkang/.ndmg/ndmg_atlases/atlases/mask/HarvardOxford-thr25_space-MNI152NLin6_variant-lateral-ventricles_res-2x2x2_descr-brainmask.nii.gz -thr 0.1 -bin /home/jialinkang/.ndmg/ndmg_atlases/atlases/mask/HarvardOxford-thr25_space-MNI152NLin6_variant-lateral-ventricles_res-2x2x2_descr-brainmask.nii.gz

# %%
t1w_wm_thr = nib.load('e:/fslmaths/HarvardOxford-thr25_space-MNI152NLin6_variant-lateral-ventricles_res-2x2x2_descr-brainmask_in.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[46])
# Out:
# (91, 109, 91)

# %%
t1w_wm_thr = nib.load('e:/fslmaths/HarvardOxford-thr25_space-MNI152NLin6_variant-lateral-ventricles_res-2x2x2_descr-brainmask.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[46])
# Out:
# (91, 109, 91)

# %% [raw]
# fslmaths /home/jialinkang/.ndmg/ndmg_atlases/atlases/mask/CorpusCallosum_res_2mm.nii.gz -bin /home/jialinkang/.ndmg/ndmg_atlases/atlases/mask/CorpusCallosum_res_2mm.nii.gz

# %%
t1w_wm_thr = nib.load('e:/fslmaths/CorpusCallosum_res_2mm.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[46])
# Out:
# (91, 109, 91)

# %% [raw]
# fslmaths /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/tmp/reg_a/t1w_vent_mask_dwi.nii.gz -kernel sphere 10 -ero -bin /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/tmp/reg_a/t1w_vent_mask_dwi.nii.gz

# %%
t1w_wm_thr = nib.load('e:/fslmaths/t1w_vent_mask_dwi.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[:,72,:])
# Out:
# (141, 141, 68)

# %% [raw]
# 'fslmaths /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/tmp/reg_a/t1w_gm_in_dwi_bin.nii.gz -mul /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/tmp/reg_a/t1w_wm_in_dwi_bin.nii.gz -add /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/anat/registered/t1w_corpuscallosum_dwi.nii.gz -sub /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/tmp/reg_a/t1w_vent_csf_in_dwi.nii.gz -mas /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/dwi/preproc/nodif_B0_bet_mask.nii.gz -bin /mnt/d/Downloads/neurodatadesign/output_data/ndmg_outputs/sub-0025864/ses-1/anat/registered/t1w_wm_gm_int_in_dwi.nii.gz'

# %%
t1w_wm_thr = nib.load('e:/fslmaths/t1w_gm_in_dwi_bin.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[:,72,:])
# Out:
# (141, 141, 68)

# %%
t1w_wm_thr = nib.load('e:/fslmaths/t1w_wm_in_dwi_bin.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[:,72,:])
# Out:
# (141, 141, 68)

# %%
t1w_wm_thr = nib.load('e:/fslmaths/t1w_vent_csf_in_dwi.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[:,72,:])
# Out:
# (141, 141, 68)

# %%
t1w_wm_thr = nib.load('e:/fslmaths/nodif_B0_bet_mask.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[:,72,:])
# Out:
# (141, 141, 68)

# %%
t1w_wm_thr = nib.load('e:/fslmaths/t1w_wm_gm_int_in_dwi.nii.gz')
t1w_wm_thr_arr = t1w_wm_thr.get_data()
print(t1w_wm_thr_arr.shape)
io.imshow(t1w_wm_thr_arr[:,72,:])
# Out:
# (141, 141, 68)
