# %% [markdown]
# # overlay between fast and dipy_replace_fast

# %% [markdown]
# ## import necessary package

# %%
from dipy.viz import regtools
import nibabel as nib
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ## show the overlay graph of different dataset

# %%
# 1st data
test_1_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o1f/sub-0021001/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_1_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o1f/sub-0021001/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_1_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o1f/sub-0021001/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_1_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o1/sub-0021001/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_1_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o1/sub-0021001/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_1_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o1/sub-0021001/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 2nd data
test_2_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o1f/sub-0021001/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_2_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o1f/sub-0021001/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_2_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o1f/sub-0021001/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_2_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o1/sub-0021001/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_2_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o1/sub-0021001/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_2_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o1/sub-0021001/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 3rd data
test_3_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o2f/sub-0021002/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_3_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o2f/sub-0021002/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_3_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o2f/sub-0021002/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_3_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o2/sub-0021002/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_3_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o2/sub-0021002/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_3_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o2/sub-0021002/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 4th data
test_4_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o2f/sub-0021002/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_4_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o2f/sub-0021002/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_4_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o2f/sub-0021002/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_4_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o2/sub-0021002/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_4_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o2/sub-0021002/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_4_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o2/sub-0021002/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 5th data
test_5_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o3f/sub-0021006/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_5_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o3f/sub-0021006/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_5_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o3f/sub-0021006/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_5_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o3/sub-0021006/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_5_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o3/sub-0021006/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_5_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o3/sub-0021006/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 6th data
test_6_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o3f/sub-0021006/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_6_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o3f/sub-0021006/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_6_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o3f/sub-0021006/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_6_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o3/sub-0021006/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_6_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o3/sub-0021006/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_6_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o3/sub-0021006/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 7th data
test_7_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o4f/sub-0021018/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_7_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o4f/sub-0021018/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_7_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o4f/sub-0021018/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_7_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o4/sub-0021018/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_7_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o4/sub-0021018/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_7_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o4/sub-0021018/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 8th data
test_8_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o4f/sub-0021018/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_8_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o4f/sub-0021018/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_8_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o4f/sub-0021018/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_8_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o4/sub-0021018/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_8_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o4/sub-0021018/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_8_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o4/sub-0021018/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 9th data
test_9_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o5f/sub-0025427/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_9_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o5f/sub-0025427/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_9_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o5f/sub-0025427/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_9_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o5/sub-0025427/ses-1/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_9_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o5/sub-0025427/ses-1/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_9_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o5/sub-0025427/ses-1/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# 10th data
test_10_csf_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o5f/sub-0025427/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_10_gm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o5f/sub-0025427/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_10_wm_fast = nib.load('D:/Downloads/neurodatadesign/output_data/o5f/sub-0025427/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

test_10_csf_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o5/sub-0025427/ses-2/anat/preproc/t1w_seg_pve_0.nii.gz').get_data()
test_10_gm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o5/sub-0025427/ses-2/anat/preproc/t1w_seg_pve_1.nii.gz').get_data()
test_10_wm_dipy = nib.load('D:/Downloads/neurodatadesign/output_data/o5/sub-0025427/ses-2/anat/preproc/t1w_seg_pve_2.nii.gz').get_data()

# %%
regtools.overlay_slices(test_1_csf_fast, test_1_csf_dipy, None, 0, 'test_1_csf_fast', 'test_1_csf_dipy')
regtools.overlay_slices(test_1_csf_fast, test_1_csf_dipy, None, 1, 'test_1_csf_fast', 'test_1_csf_dipy')
regtools.overlay_slices(test_1_csf_fast, test_1_csf_dipy, None, 2, 'test_1_csf_fast', 'test_1_csf_dipy')

# %%
regtools.overlay_slices(test_1_gm_fast, test_1_gm_dipy, None, 0, 'test_1_gm_fast', 'test_1_gm_dipy')
regtools.overlay_slices(test_1_gm_fast, test_1_gm_dipy, None, 1, 'test_1_gm_fast', 'test_1_gm_dipy')
regtools.overlay_slices(test_1_gm_fast, test_1_gm_dipy, None, 2, 'test_1_gm_fast', 'test_1_gm_dipy')

# %%
regtools.overlay_slices(test_1_wm_fast, test_1_wm_dipy, None, 0, 'test_1_wm_fast', 'test_1_wm_dipy')
regtools.overlay_slices(test_1_wm_fast, test_1_wm_dipy, None, 1, 'test_1_wm_fast', 'test_1_wm_dipy')
regtools.overlay_slices(test_1_wm_fast, test_1_wm_dipy, None, 2, 'test_1_wm_fast', 'test_1_wm_dipy')

# %%
regtools.overlay_slices(test_2_csf_fast, test_2_csf_dipy, None, 0, 'test_2_csf_fast', 'test_2_csf_dipy')
regtools.overlay_slices(test_2_csf_fast, test_2_csf_dipy, None, 1, 'test_2_csf_fast', 'test_2_csf_dipy')
regtools.overlay_slices(test_2_csf_fast, test_2_csf_dipy, None, 2, 'test_2_csf_fast', 'test_2_csf_dipy')

# %%
regtools.overlay_slices(test_2_gm_fast, test_2_gm_dipy, None, 0, 'test_2_gm_fast', 'test_2_gm_dipy')
regtools.overlay_slices(test_2_gm_fast, test_2_gm_dipy, None, 1, 'test_2_gm_fast', 'test_2_gm_dipy')
regtools.overlay_slices(test_2_gm_fast, test_2_gm_dipy, None, 2, 'test_2_gm_fast', 'test_2_gm_dipy')

# %%
regtools.overlay_slices(test_2_wm_fast, test_2_wm_dipy, None, 0, 'test_2_wm_fast', 'test_2_wm_dipy')
regtools.overlay_slices(test_2_wm_fast, test_2_wm_dipy, None, 1, 'test_2_wm_fast', 'test_2_wm_dipy')
regtools.overlay_slices(test_2_wm_fast, test_2_wm_dipy, None, 2, 'test_2_wm_fast', 'test_2_wm_dipy')

# %%
regtools.overlay_slices(test_3_csf_fast, test_3_csf_dipy, None, 0, 'test_3_csf_fast', 'test_3_csf_dipy')
regtools.overlay_slices(test_3_csf_fast, test_3_csf_dipy, None, 1, 'test_3_csf_fast', 'test_3_csf_dipy')
regtools.overlay_slices(test_3_csf_fast, test_3_csf_dipy, None, 2, 'test_3_csf_fast', 'test_3_csf_dipy')

# %%
regtools.overlay_slices(test_3_gm_fast, test_3_gm_dipy, None, 0, 'test_3_gm_fast', 'test_3_gm_dipy')
regtools.overlay_slices(test_3_gm_fast, test_3_gm_dipy, None, 1, 'test_3_gm_fast', 'test_3_gm_dipy')
regtools.overlay_slices(test_3_gm_fast, test_3_gm_dipy, None, 2, 'test_3_gm_fast', 'test_3_gm_dipy')

# %%
regtools.overlay_slices(test_3_wm_fast, test_3_wm_dipy, None, 0, 'test_3_wm_fast', 'test_3_wm_dipy')
regtools.overlay_slices(test_3_wm_fast, test_3_wm_dipy, None, 1, 'test_3_wm_fast', 'test_3_wm_dipy')
regtools.overlay_slices(test_3_wm_fast, test_3_wm_dipy, None, 2, 'test_3_wm_fast', 'test_3_wm_dipy')

# %%
regtools.overlay_slices(test_4_csf_fast, test_4_csf_dipy, None, 0, 'test_4_csf_fast', 'test_4_csf_dipy')
regtools.overlay_slices(test_4_csf_fast, test_4_csf_dipy, None, 1, 'test_4_csf_fast', 'test_4_csf_dipy')
regtools.overlay_slices(test_4_csf_fast, test_4_csf_dipy, None, 2, 'test_4_csf_fast', 'test_4_csf_dipy')

# %%
regtools.overlay_slices(test_4_gm_fast, test_4_gm_dipy, None, 0, 'test_4_gm_fast', 'test_4_gm_dipy')
regtools.overlay_slices(test_4_gm_fast, test_4_gm_dipy, None, 1, 'test_4_gm_fast', 'test_4_gm_dipy')
regtools.overlay_slices(test_4_gm_fast, test_4_gm_dipy, None, 2, 'test_4_gm_fast', 'test_4_gm_dipy')

# %%
regtools.overlay_slices(test_4_wm_fast, test_4_wm_dipy, None, 0, 'test_4_wm_fast', 'test_4_wm_dipy')
regtools.overlay_slices(test_4_wm_fast, test_4_wm_dipy, None, 1, 'test_4_wm_fast', 'test_4_wm_dipy')
regtools.overlay_slices(test_4_wm_fast, test_4_wm_dipy, None, 2, 'test_4_wm_fast', 'test_4_wm_dipy')

# %%
regtools.overlay_slices(test_5_csf_fast, test_5_csf_dipy, None, 0, 'test_5_csf_fast', 'test_5_csf_dipy')
regtools.overlay_slices(test_5_csf_fast, test_5_csf_dipy, None, 1, 'test_5_csf_fast', 'test_5_csf_dipy')
regtools.overlay_slices(test_5_csf_fast, test_5_csf_dipy, None, 2, 'test_5_csf_fast', 'test_5_csf_dipy')

# %%
regtools.overlay_slices(test_5_gm_fast, test_5_gm_dipy, None, 0, 'test_5_gm_fast', 'test_5_gm_dipy')
regtools.overlay_slices(test_5_gm_fast, test_5_gm_dipy, None, 1, 'test_5_gm_fast', 'test_5_gm_dipy')
regtools.overlay_slices(test_5_gm_fast, test_5_gm_dipy, None, 2, 'test_5_gm_fast', 'test_5_gm_dipy')

# %%
regtools.overlay_slices(test_5_wm_fast, test_5_wm_dipy, None, 0, 'test_5_wm_fast', 'test_5_wm_dipy')
regtools.overlay_slices(test_5_wm_fast, test_5_wm_dipy, None, 1, 'test_5_wm_fast', 'test_5_wm_dipy')
regtools.overlay_slices(test_5_wm_fast, test_5_wm_dipy, None, 2, 'test_5_wm_fast', 'test_5_wm_dipy')

# %%
regtools.overlay_slices(test_6_csf_fast, test_6_csf_dipy, None, 0, 'test_6_csf_fast', 'test_6_csf_dipy')
regtools.overlay_slices(test_6_csf_fast, test_6_csf_dipy, None, 1, 'test_6_csf_fast', 'test_6_csf_dipy')
regtools.overlay_slices(test_6_csf_fast, test_6_csf_dipy, None, 2, 'test_6_csf_fast', 'test_6_csf_dipy')

# %%
regtools.overlay_slices(test_6_gm_fast, test_6_gm_dipy, None, 0, 'test_6_gm_fast', 'test_6_gm_dipy')
regtools.overlay_slices(test_6_gm_fast, test_6_gm_dipy, None, 1, 'test_6_gm_fast', 'test_6_gm_dipy')
regtools.overlay_slices(test_6_gm_fast, test_6_gm_dipy, None, 2, 'test_6_gm_fast', 'test_6_gm_dipy')

# %%
regtools.overlay_slices(test_6_wm_fast, test_6_wm_dipy, None, 0, 'test_6_wm_fast', 'test_6_wm_dipy')
regtools.overlay_slices(test_6_wm_fast, test_6_wm_dipy, None, 1, 'test_6_wm_fast', 'test_6_wm_dipy')
regtools.overlay_slices(test_6_wm_fast, test_6_wm_dipy, None, 2, 'test_6_wm_fast', 'test_6_wm_dipy')

# %%
regtools.overlay_slices(test_7_csf_fast, test_7_csf_dipy, None, 0, 'test_7_csf_fast', 'test_7_csf_dipy')
regtools.overlay_slices(test_7_csf_fast, test_7_csf_dipy, None, 1, 'test_7_csf_fast', 'test_7_csf_dipy')
regtools.overlay_slices(test_7_csf_fast, test_7_csf_dipy, None, 2, 'test_7_csf_fast', 'test_7_csf_dipy')

# %%
regtools.overlay_slices(test_7_gm_fast, test_7_gm_dipy, None, 0, 'test_7_gm_fast', 'test_7_gm_dipy')
regtools.overlay_slices(test_7_gm_fast, test_7_gm_dipy, None, 1, 'test_7_gm_fast', 'test_7_gm_dipy')
regtools.overlay_slices(test_7_gm_fast, test_7_gm_dipy, None, 2, 'test_7_gm_fast', 'test_7_gm_dipy')

# %%
regtools.overlay_slices(test_7_wm_fast, test_7_wm_dipy, None, 0, 'test_7_wm_fast', 'test_7_wm_dipy')
regtools.overlay_slices(test_7_wm_fast, test_7_wm_dipy, None, 1, 'test_7_wm_fast', 'test_7_wm_dipy')
regtools.overlay_slices(test_7_wm_fast, test_7_wm_dipy, None, 2, 'test_7_wm_fast', 'test_7_wm_dipy')

# %%
regtools.overlay_slices(test_8_csf_fast, test_8_csf_dipy, None, 0, 'test_8_csf_fast', 'test_8_csf_dipy')
regtools.overlay_slices(test_8_csf_fast, test_8_csf_dipy, None, 1, 'test_8_csf_fast', 'test_8_csf_dipy')
regtools.overlay_slices(test_8_csf_fast, test_8_csf_dipy, None, 2, 'test_8_csf_fast', 'test_8_csf_dipy')

# %%
regtools.overlay_slices(test_8_gm_fast, test_8_gm_dipy, None, 0, 'test_8_gm_fast', 'test_8_gm_dipy')
regtools.overlay_slices(test_8_gm_fast, test_8_gm_dipy, None, 1, 'test_8_gm_fast', 'test_8_gm_dipy')
regtools.overlay_slices(test_8_gm_fast, test_8_gm_dipy, None, 2, 'test_8_gm_fast', 'test_8_gm_dipy')

# %%
regtools.overlay_slices(test_8_wm_fast, test_8_wm_dipy, None, 0, 'test_8_wm_fast', 'test_8_wm_dipy')
regtools.overlay_slices(test_8_wm_fast, test_8_wm_dipy, None, 1, 'test_8_wm_fast', 'test_8_wm_dipy')
regtools.overlay_slices(test_8_wm_fast, test_8_wm_dipy, None, 2, 'test_8_wm_fast', 'test_8_wm_dipy')

# %%
regtools.overlay_slices(test_9_csf_fast, test_9_csf_dipy, None, 0, 'test_9_csf_fast', 'test_9_csf_dipy')
regtools.overlay_slices(test_9_csf_fast, test_9_csf_dipy, None, 1, 'test_9_csf_fast', 'test_9_csf_dipy')
regtools.overlay_slices(test_9_csf_fast, test_9_csf_dipy, None, 2, 'test_9_csf_fast', 'test_9_csf_dipy')

# %%
regtools.overlay_slices(test_9_gm_fast, test_9_gm_dipy, None, 0, 'test_9_gm_fast', 'test_9_gm_dipy')
regtools.overlay_slices(test_9_gm_fast, test_9_gm_dipy, None, 1, 'test_9_gm_fast', 'test_9_gm_dipy')
regtools.overlay_slices(test_9_gm_fast, test_9_gm_dipy, None, 2, 'test_9_gm_fast', 'test_9_gm_dipy')

# %%
regtools.overlay_slices(test_9_wm_fast, test_9_wm_dipy, None, 0, 'test_9_wm_fast', 'test_9_wm_dipy')
regtools.overlay_slices(test_9_wm_fast, test_9_wm_dipy, None, 1, 'test_9_wm_fast', 'test_9_wm_dipy')
regtools.overlay_slices(test_9_wm_fast, test_9_wm_dipy, None, 2, 'test_9_wm_fast', 'test_9_wm_dipy')

# %%
regtools.overlay_slices(test_10_csf_fast, test_10_csf_dipy, None, 0, 'test_10_csf_fast', 'test_10_csf_dipy')
regtools.overlay_slices(test_10_csf_fast, test_10_csf_dipy, None, 1, 'test_10_csf_fast', 'test_10_csf_dipy')
regtools.overlay_slices(test_10_csf_fast, test_10_csf_dipy, None, 2, 'test_10_csf_fast', 'test_10_csf_dipy')

# %%
regtools.overlay_slices(test_10_gm_fast, test_10_gm_dipy, None, 0, 'test_10_gm_fast', 'test_10_gm_dipy')
regtools.overlay_slices(test_10_gm_fast, test_10_gm_dipy, None, 1, 'test_10_gm_fast', 'test_10_gm_dipy')
regtools.overlay_slices(test_10_gm_fast, test_10_gm_dipy, None, 2, 'test_10_gm_fast', 'test_10_gm_dipy')

# %%
regtools.overlay_slices(test_10_wm_fast, test_10_wm_dipy, None, 0, 'test_10_wm_fast', 'test_10_wm_dipy')
regtools.overlay_slices(test_10_wm_fast, test_10_wm_dipy, None, 1, 'test_10_wm_fast', 'test_10_wm_dipy')
regtools.overlay_slices(test_10_wm_fast, test_10_wm_dipy, None, 2, 'test_10_wm_fast', 'test_10_wm_dipy')

# %% [markdown]
# # show the differance percentage between the FAST and dipy_FAST

# %% [markdown]
# ## the function of dice

# %%
def dice_score(A,B):
    """
    A: Baseline numpy array to be compared
    B: Alternative numpy arrray to be compared
    
    out: dice score
    """
    #smooth
    smooth = 1.0
    #convert to torch tensor and flatten
    A_flat = torch.from_numpy(A).contiguous().view(-1)
    B_flat = torch.from_numpy(B).contiguous().view(-1)
    
    #calc dice components
    intersection = (A_flat * B_flat).sum()
    A_sum = torch.sum(A_flat*A_flat)
    B_sum = torch.sum(B_flat*B_flat)
    
    #calc dice
    dice = (2. * intersection + smooth)/(A_sum + B_sum + smooth)
    
    return dice

# %% [markdown]
# ## the differance percentage

# %%
print(dice_score(test_1_csf_fast, test_1_csf_dipy))
print(dice_score(test_1_gm_fast, test_1_gm_dipy))
print(dice_score(test_1_wm_fast, test_1_wm_dipy))
# Out:
# tensor(0.8609, dtype=torch.float64)
# tensor(0.7004, dtype=torch.float64)
# tensor(0.7950, dtype=torch.float64)

# %%
print(dice_score(test_2_csf_fast, test_2_csf_dipy))
print(dice_score(test_2_gm_fast, test_2_gm_dipy))
print(dice_score(test_2_wm_fast, test_2_wm_dipy))
# Out:
# tensor(0.8609, dtype=torch.float64)
# tensor(0.7004, dtype=torch.float64)
# tensor(0.7950, dtype=torch.float64)

# %%
print(dice_score(test_3_csf_fast, test_3_csf_dipy))
print(dice_score(test_3_gm_fast, test_3_gm_dipy))
print(dice_score(test_3_wm_fast, test_3_wm_dipy))
# Out:
# tensor(0.9353, dtype=torch.float64)
# tensor(0.9167, dtype=torch.float64)
# tensor(0.9569, dtype=torch.float64)

# %%
print(dice_score(test_4_csf_fast, test_4_csf_dipy))
print(dice_score(test_4_gm_fast, test_4_gm_dipy))
print(dice_score(test_4_wm_fast, test_4_wm_dipy))
# Out:
# tensor(0.9353, dtype=torch.float64)
# tensor(0.9167, dtype=torch.float64)
# tensor(0.9569, dtype=torch.float64)

# %%
print(dice_score(test_5_csf_fast, test_5_csf_dipy))
print(dice_score(test_5_gm_fast, test_5_gm_dipy))
print(dice_score(test_5_wm_fast, test_5_wm_dipy))
# Out:
# tensor(0.9279, dtype=torch.float64)
# tensor(0.9058, dtype=torch.float64)
# tensor(0.9446, dtype=torch.float64)

# %%
print(dice_score(test_6_csf_fast, test_6_csf_dipy))
print(dice_score(test_6_gm_fast, test_6_gm_dipy))
print(dice_score(test_6_wm_fast, test_6_wm_dipy))
# Out:
# tensor(0.9279, dtype=torch.float64)
# tensor(0.9058, dtype=torch.float64)
# tensor(0.9446, dtype=torch.float64)

# %%
print(dice_score(test_7_csf_fast, test_7_csf_dipy))
print(dice_score(test_7_gm_fast, test_7_gm_dipy))
print(dice_score(test_7_wm_fast, test_7_wm_dipy))
# Out:
# tensor(0.9206, dtype=torch.float64)
# tensor(0.9063, dtype=torch.float64)
# tensor(0.9494, dtype=torch.float64)

# %%
print(dice_score(test_8_csf_fast, test_8_csf_dipy))
print(dice_score(test_8_gm_fast, test_8_gm_dipy))
print(dice_score(test_8_wm_fast, test_8_wm_dipy))
# Out:
# tensor(0.9206, dtype=torch.float64)
# tensor(0.9063, dtype=torch.float64)
# tensor(0.9494, dtype=torch.float64)

# %%
print(dice_score(test_9_csf_fast, test_9_csf_dipy))
print(dice_score(test_9_gm_fast, test_9_gm_dipy))
print(dice_score(test_9_wm_fast, test_9_wm_dipy))
# Out:
# tensor(0.9330, dtype=torch.float64)
# tensor(0.8688, dtype=torch.float64)
# tensor(0.9574, dtype=torch.float64)

# %%
print(dice_score(test_10_csf_fast, test_10_csf_dipy))
print(dice_score(test_10_gm_fast, test_10_gm_dipy))
print(dice_score(test_10_wm_fast, test_10_wm_dipy))
# Out:
# tensor(0.8365, dtype=torch.float64)
# tensor(0.7011, dtype=torch.float64)
# tensor(0.9061, dtype=torch.float64)
